# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
link='https://www.passiton.com/inspirational-quotes'
html_text=requests.get(link).text
bs=BeautifulSoup(html_text,'lxml')

# %%
html = bs.find('div',attrs={"class":"col-8 d-flex flex-column justify-content-top text-center"})
html
# Out:
# <div class="col-8 d-flex flex-column justify-content-top text-center">
# <div class="row" id="all_quotes">
# <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
# <a href="/inspirational-quotes/6258-a-smile-is-a-curve-that-sets-everything-straight"><img alt="A smile is a curve that sets everything straight.  #&lt;Author:0x00007ff680532a90&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6258/medium/20220908_thursday_quote.jpg" width="310"/></a>
# <h5 class="value_on_red"><a href="/inspirational-quotes/6258-a-smile-is-a-curve-that-sets-everything-straight">SMILE</a></h5>
# </div>
# <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
# ...

# %%
x=html.find_all('a')
qoutes_link=[]
image_link=[]
qoutes=[]
category=[]

# quoute link
for i in x:
    qoutes_link.append(i['href'])
    
print(len(q_link))
# Out:
# 66

# %%
y=html.find_all('img')
# quotes & image url
for a in y:
    qoutes.append(a['alt'])
    image_link.append(a['src'])
    
y=table.find_all('h5')

# %%
for f in y:
    category.append(f.find(text=True).strip())

# %%
scraped_data=[]
dictionary={}
dictionary['image link']=image_link
dictionary['category']=category
dictionary['qoutes link']=qoutes_link
dictionary['qoutes']=qoutes

# %%
df=pd.DataFrame.from_dict(dictionary)
df
# Out:
#                                            image link    category  \
# 0   https://assets.passiton.com/quotes/quote_artwo...       SMILE
# 1   https://assets.passiton.com/quotes/quote_artwo...       SMILE
# 2   https://assets.passiton.com/quotes/quote_artwo...       SMILE
# 3   https://assets.passiton.com/quotes/quote_artwo...       SMILE
# 4   https://assets.passiton.com/quotes/quote_artwo...       PEACE
# ..                                                ...         ...
# 61  https://assets.passiton.com/quotes/quote_artwo...  CONFIDENCE
# 62  https://assets.passiton.com/quotes/quote_artwo...    KINDNESS
# 63  https://assets.passiton.com/quotes/quote_artwo...    KINDNESS
# 64  https://assets.passiton.com/quotes/quote_artwo...    KINDNESS
# 65  https://assets.passiton.com/quotes/quote_artwo...    KINDNESS
#
#                                           qoutes link  \
# 0   /inspirational-quotes/6258-a-smile-is-a-curve-...
# 1   /inspirational-quotes/6258-a-smile-is-a-curve-...
# ...

# %%
df.to_csv('result1.csv', index=False)
